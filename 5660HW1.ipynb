# %% [markdown]
# # Homework 1

# %% [markdown]
# ### Installing packages

# %%
# !pip install langchain_google_genai
# Out:
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-4.2.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain_google_genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.56.0 (from langchain_google_genai)
#   Downloading google_genai-1.59.0-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (2.12.3)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.12.1)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai)
#   Downloading google_auth-2.47.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.6.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.13.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.6.1)
# Downloading langchain_google_genai-4.2.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.59.0-py3-none-any.whl (719 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.1/719.1 kB 16.8 MB/s eta 0:00:00
# Downloading google_auth-2.47.0-py3-none-any.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.9/234.9 kB 17.0 MB/s eta 0:00:00
# Installing collected packages: filetype, google-auth, google-genai, langchain_google_genai
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.43.0
#     Uninstalling google-auth-2.43.0:
#       Successfully uninstalled google-auth-2.43.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.55.0
#     Uninstalling google-genai-1.55.0:
#       Successfully uninstalled google-genai-1.55.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.47.0 which is incompatible.
# Successfully installed filetype-1.2.0 google-auth-2.47.0 google-genai-1.59.0 langchain_google_genai-4.2.0

# %% [markdown]
# ## Setup your API key
#
# To run the following cell, your API key must be stored it in a Colab Secret named `VERTEX_API_KEY`.
#
#
# 1.   Look for the key icon on the left panel of your colab.
# 2.   Under `Name`, create `VERTEX_API_KEY`.
# 3. Copy your key to `Value`.

# %%
from google.colab import userdata
GEMINI_VERTEX_API_KEY = userdata.get('VERTEX_API_KEY')

# %% [markdown]
# ## Downloading receipts.zip
# The codes below download and unzip receipts.zip from Google Drive. receipts.zip contains all images from the Fusion folder on BlackBoard.

# %%
import gdown
file_id = "1oe2FZd3ZTO7nrDqjCafNvxicl08oF8JF"
download_url = f"https://drive.google.com/uc?id={file_id}"
gdown.download(download_url, "receipts.zip", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oe2FZd3ZTO7nrDqjCafNvxicl08oF8JF
# To: /content/receipts.zip
# 100%|██████████| 1.61M/1.61M [00:00<00:00, 98.9MB/s]
# 'receipts.zip'

# %%
# !unzip receipts.zip
# Out:
# Archive:  receipts.zip
#   inflating: receipt1.jpg
#   inflating: __MACOSX/._receipt1.jpg
#   inflating: receipt2.jpg
#   inflating: __MACOSX/._receipt2.jpg
#   inflating: receipt3.jpg
#   inflating: __MACOSX/._receipt3.jpg
#   inflating: receipt4.jpg
#   inflating: __MACOSX/._receipt4.jpg
#   inflating: receipt5.jpg
#   inflating: __MACOSX/._receipt5.jpg
#   inflating: receipt6.jpg
#   inflating: __MACOSX/._receipt6.jpg
#   inflating: receipt7.jpg
#   inflating: __MACOSX/._receipt7.jpg

# %% [markdown]
# ## 1. Helper functions
#
# We need two functions
# * image_to_base64 convert your jpg image into Base64 encoded string (basically a sequence of 64 characters to make your image easily transfered via API)
# * get_image_data_url takes your jpg image, converting them into base64 string and construct a suitable input for GEMINI api call.

# %%
import base64
import mimetypes

# Helper function to read and encode image
def image_to_base64(img_path):
    with open(img_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode('utf-8')

# Helper function to encode local file to Base64 Data URL
def get_image_data_url(image_path):
    # Guess the mime type (e.g., image/png, image/jpeg) based on file extension
    mime_type, _ = mimetypes.guess_type(image_path)
    if mime_type is None:
        mime_type = "image/png" # Default fallback

    encoded_string = image_to_base64(image_path)

    # Construct the Data URL
    return f"data:{mime_type};base64,{encoded_string}"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key=userdata.get('VERTEX_API_KEY'), # Ensure this key is set in Colab secrets
    temperature=0
)

# %% [markdown]
# Display jpg images. Alternatively, open the folder icon on the left pannel to see the images.

# %%
from IPython.display import HTML, display
import glob, os

image_paths = glob.glob("*.jpg")
image_paths.sort()
html_content = '<div style="display: flex; flex-wrap: wrap; gap: 20px;">'

for path in image_paths:
    b64 = image_to_base64(path)
    filename = os.path.basename(path) # Clean up path to show just the name

    # Create a vertical column for each image + text
    html_content += f'''
    <div style="display: flex; flex-direction: column; align-items: center;">
        <img src="data:image/jpeg;base64,{b64}" style="height: 300px; border: 1px solid #ddd; margin-bottom: 5px;"/>
        <span style="font-family: monospace; font-size: 14px;">{filename}</span>
    </div>
    '''

html_content += '</div>'

display(HTML(html_content))
# Out:
# <div style="display: flex; flex-wrap: wrap; gap: 20px;"></div>

# %% [markdown]
# ## 2. Image input to Gemini
# Different from text, image needs to be converted into base64 encoded string and then formated into url before inputting to the language model. This is convenient for image-type input to be transfered through the API.
#
# You can find out more appropriate format for image-type data in this [Link](https://docs.langchain.com/oss/python/langchain/messages)

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant.You analyze receipt content without missing"),
    ("human", [
        {"type": "text", "text": "{question}"},
        {"type": "image_url", "image_url": {"url": "{image_url}"}},
        {"type": "text", "text": "add a line of ----begin---- indicate the beginning of the response and a create a new line ----end---- at the end  of the response"}
    ]),
])

chain = prompt | llm
receipt_content = ""
for i in range(1,8):
  image_path = f"/content/receipt{i}.jpg"
  image_data_url = get_image_data_url(image_path)
  response = chain.invoke({
      "question": "What is in this picture?",
      "image_url": image_data_url
  })
  if i == 1:
    receipt_content=response.content
  else:
    receipt_content+="\n"+f"receipt session {i}" +response.content # Added newline here

print(receipt_content)
# Out:
# ----begin----
# This picture is a receipt from a grocery or supermarket, likely in Hong Kong given the currency and language.
#
# Here's a breakdown of the content:
#
# **Items Purchased:**
#
# *   **084213 韭菜豬肉雲吞20粒裝 (Chive Pork Wonton 20 pcs)**
#     *   Quantity: 1
#     *   Price: $24.90
#     *   Discount: -$12.40
# *   **084213 韭菜豬肉雲吞20粒裝 (Chive Pork Wonton 20 pcs)**
#     *   Quantity: 1
#     *   Price: $24.90
#     *   Discount: -$12.40
# *   **084213 韭菜豬肉雲吞20粒裝 (Chive Pork Wonton 20 pcs)**
#     *   Quantity: 1
#     *   Price: $24.90
#     *   Discount: -$12.40
# *   **395092 IF100% COCONUT WATER**
#     *   Quantity: 2
#     *   Price: $57.80
#     *   Discount (Buy 2 Save $12.8): -$12.80
# *   **044228 玉芒 (Mango)**
#     *   Quantity: 3
#     *   Price: $29.70
#     *   Discount (Buy 3 Save $10.8): -$10.80
# *   **490948 Fresh綜合莓汁 (Fresh Mixed Berry Juice)**
#     *   Quantity: 2
#     *   Price: $35.80
#     *   Discount (Buy 2 Save $3.9): -$3.90
# *   **126894 雀巢脫脂高鈣牛奶飲品 (Nestle Skimmed High Calcium Milk Drink)**
#     *   Quantity: 1
#     *   Price: $21.90
# *   **055421 蔬菜先生包裝蕃茄 (Mr. Vegetable Packaged Tomatoes)**
#     *   Quantity: 1
#     *   Price: $9.90
# *   **047827 蔬菜先生翠玉瓜1磅 (Mr. Vegetable Zucchini 1lb)**
#     *   Quantity: 1
#     *   Price: $7.90
# *   **089288 咸蛋蒸肉餅 (Steamed Pork Patty with Salted Egg)**
#     *   Quantity: 1
#     *   Price: $36.90
# *   **118700 金御膳龍口粉絲 (Golden Imperial Vermicelli)**
#     *   Quantity: 2
#     *   Price: $23.80
# *   **013723 (業務用) 急凍蟶子肉 (Frozen Razor Clams (for commercial use))**
#     *   Quantity: 2
#     *   Price: $130.00
# *   **047610 白柳姬菇 (White Shimeji Mushrooms)**
#     *   Quantity: 1
#     *   Price: $14.90
# *   **089376 蒜汁雞扒 (Garlic Sauce Chicken Chop)**
#     *   Quantity: 1
#     *   Price: $36.90
#
# **Discounts and Totals:**
#
# *   **5% OFF (CU):** -$20.78
# *   **20 小計 (Subtotal):** $394.72
# *   **ROUNDING:** -$0.02
# *   **OCTOPUS (Total after rounding):** $394.70
# *   **找續 (Change):** $0.00
#
# **Payment Information:**
#
# *   **機號 (Machine No.):** 515214
# *   **八達通卡號碼 (Octopus Card No.):** 172731824
# *   **扣除金額 (Amount Deducted):** $394.70
# *   **餘額 (Remaining Balance):** -$15.90 (This likely indicates the remaining balance on the Octopus card after the transaction, or a negative balance if it was topped up, but given the "扣除金額" it's more likely the remaining balance on the card was $15.90 after the purchase, meaning the card had more than enough funds.)
# *   **上一次於 2025-04-10 網上增值 (Last online top-up on 2025-04-10)**
#
# **Other Information:**
#
# *   **收銀員姓名 (Cashier Name):** JL
# *   **收銀員 (Cashier ID):** 1234
#
# The receipt details a purchase of various food items including wontons, coconut water, mangoes, juice, milk, vegetables, a pork patty, vermicelli, razor clams, mushrooms, and chicken chop. Several items received discounts for multi-buy promotions, and there was an additional 5% off. The total amount paid was $394.70 via Octopus card.
# ----end----
# receipt session 2----begin----
# This picture is a receipt from **Fusion** (PARKnSHOP (HK) Limited).
#
# Here's a detailed breakdown of the content:
#
# **Store Information:**
# *   **Store Name:** Fusion (PARKnSHOP (HK) Limited)
# *   **Location:** Basement New Staff Student Ctr Bldg., Chinese University of HK, Shatin, NT
# *   **Tel:** 26035432
# *   **Store ID:** 00062
# *   **Register:** 027
# *   **Cashier:** 9982
#
# **Transaction Details:**
# *   **Ticket #:** 0055
# *   **Date:** 30/05/25
# *   **Time:** 17:29:51
#
# **Loyalty Program (MoneyBack):**
# *   **Card no:** 9915006109***
# *   **MoneyBack Point Balance:** 958
# *   **Points Earned in this purchase:** 63 (basic & extra pts included)
# *   **Website for more info:** www.moneyback.com.hk
#
# **Purchased Items & Prices:**
# *   309455 PLASTIC BAG CHARGIN: $1.00
# *   327395 COUPON: $0.00
# *   044228 JADE MANGO (QTY: 3): $29.70
#     *   *Buy 3 Save $9.8:* -$9.80
# *   120231 DORITOS NACHO CHEESE (QTY: 2): $31.00
#     *   *Buy 2 Save $6:* -$6.00
# *   378845 MUSO SOUR AND SPICY (QTY: 2): $29.80
#     *   *Buy 2 Save $5.9:* -$5.90
# *   476744 SELECT FISH & CUTTL (QTY: 2): $31.80
#     *   *Buy 2 Save $5.8:* -$5.80
# *   124605 QUAKER QUICK COOKING (QTY: 2): $19.80
#     *   *Buy 2 Save $2:* -$2.00
# *   385883 JAX COCO 100 PURE CO (QTY: 2): $26.00
# *   089367 FARMFRESH BLACK PEPP (QTY: 2): $91.80
# *   496134 VCODE-CANNED/BOXED A: $0.00
# *   112616 YAKULT PROBIOTICS DR: $28.90
# *   130509 TRAPPIST HI-CAL LOW: $22.90
# *   MB APP UPGRADE -$10: -$10.00
# *   075206 ORGANIC SOYA BEAN S: $15.90
# *   496133 VCODE: $0.00
# *   135366 CASTLE SOFT PACK FAC: $11.90
# *   099352 FRENCH BEAN (CHINA) (QTY: 2): $19.80
# *   034930 OWN RUN BAKERY BREAD: $16.00
# *   417130 INDOMIE MI GORENG 5: $15.90
# *   App Upgrad$350-$20_C: -$20.00
# *   5% OFF (CU-SCO): -$16.59
#
# **Summary of Charges:**
# *   **SUBTOTAL (26 items):** $316.11
# *   **ROUNDING:** -$0.01
# *   **OCTOPUS:** $316.10
# *   **CHANGE:** $0.00
#
# **Payment Information:**
# *   **Device No.:** 5112FD
# *   **Octopus Card No.:** 37023070
# *   **Amount Deducted:** $316.10
# *   **Remaining Value (on Octopus card):** $130.10
# *   **Last Add Value by Online on:** 2025-05-30
#
# **General Information/Policy:**
# *   "Original receipt needed for refund/exchange within 7 days. Excludes selected products. Visit PNS website for details. Excludes borrow shopping trolley deposit."
# *   The Chinese text reiterates the return policy: "如需退換或退款，請於七天內帶同貨品及收據正本到本店。不適用於指定產品，詳情請參閱網站。借用購物車按金除外。" (For returns or refunds, please bring the goods and the original receipt to the store within seven days. Not applicable to designated products, please refer to the website for details. Excludes shopping trolley deposit.)
# *   **Company:** 百佳超級市場(香港)有限公司 PARKnSHOP (HK) Limited
#
# **Barcode:**
# *   870622717295120250530
# ----end----
# receipt session 3----begin----
# This picture shows a receipt from a purchase. Here's a breakdown of its content:
#
# **Store Information:**
# *   **Location:** Basement New Staff Student Ctr Bldg., Chinese University of HK, Shatin, NT
# *   **Store ID:** 00062
# *   **Register:** 028
# *   **Cashier:** 9982
# *   **Cashier Name:** SCO
#
# **Transaction Details:**
# *   **Date:** 01/06/25 (likely June 1, 2025, or January 6, 2025, depending on date format convention)
# *   **Time:** 13:21:51
# *   **Ticket #:** 0022
#
# **MoneyBack Program Information:**
# *   **Card no:** 9915006056***
# *   **MoneyBack Point Balance:** 145
# *   **Points Earned in this purchase:** 28 (basic & extra pts included)
# *   **Website:** www.moneyback.com.hk
#
# **Items Purchased:**
# 1.  **440615 IF 100% COCONUT WAT**
#     *   QTY: 2
#     *   Price: $19.60
#     *   Discount: Buy 2 Save $4 (-$4.00)
# 2.  **173831 FRESH ORANGE JUICE**
#     *   QTY: 2
#     *   Price: $35.80
# 3.  **144094 FRESH PINK GUAVA JUI**
#     *   QTY: 2
#     *   Price: $35.80
#     *   Discount: Buy 2 Save $3.9 (-$7.80)
# 4.  **032580 CHARCOAL-GRILL CHIC**
#     *   Price: $15.00
# 5.  **026998 SANDWICH FACTORY TUN**
#     *   Price: $15.00
# 6.  **048738 ANDES RED CHERRY TO**
#     *   Price: $17.90
# 7.  **034930 OWN RUN BAKERY BREAD**
#     *   Price: $16.00
# 8.  **028499 OWN RUN BAKERY BAKER**
#     *   Price: $5.00
#     *   Discount: 5% OFF (CU-SCO) (-$7.42)
#
# **Summary of Charges:**
# *   **Subtotal (11 items):** $140.88
# *   **Rounding:** -$0.08
# *   **Total:** $140.80
#
# **Payment Information:**
# *   **Payment Method:** Octopus Card
# *   **Device No.:** 51788F
# *   **Octopus Card No.:** 172731824
# *   **Amount Deducted:** $140.80
# *   **Remaining Value:** $8.90
# *   **Last Add Value by Online on:** 2025-05-30
#
# **Return Policy (in Chinese, partially visible):**
# *   "如需退換或退款, 請於七天內帶同貨品及收據正本到本店。" (If you need to exchange or refund, please bring the goods and the original receipt to this store within seven days.)
# *   Followed by text about "不適用於指定產品" (not applicable to designated products) and "詳情請參閱網站" (for details, please refer to the website).
# ----end----
# receipt session 4----begin----
# This is a receipt from **fusion** (PARKnSHOP (HK) Limited) at the **Chinese University** branch.
#
# Here's a breakdown of the content:
#
# **Store Information:**
# *   **Store Name:** fusion (PARKnSHOP (HK) Limited)
# *   **Supervisor:** #1026
# *   **Branch:** Chinese University
# *   **Tel:** 2603 5432
# *   **Store No.:** 00062
# *   **Cashier Name:** Ying
# *   **Cashier No.:** 1643
# *   **Machine No.:** 004
#
# **Transaction Details:**
# *   **Date:** 19/04/25 (likely April 19, 2025, given the format and "上次於 2025-04-18 網上增值" which means "Last top-up online on 2025-04-18")
# *   **Time:** 13:35:20
# *   **Receipt Number (partial):** 9915006109***
# *   **Points Earned:** 856 (basic), 102 (additional)
#
# **Items Purchased:**
# *   **膠袋收費 (Plastic Bag Charge):** Quantity 2, Price $2.00
# *   **VCODE:** Price $0.00 (likely a coupon or discount code)
# *   **泰國水仙芒 (Thai Mango):** Quantity 2, Price $28.00
#     *   *Discount:* Buy 2 Save $4 (-$4.00)
# *   **Fresh奇異果汁 (Fresh Kiwi Juice):** Quantity 2, Price $35.80
# *   **Fresh橙汁 (Fresh Orange Juice):** Quantity 2, Price $35.80
#     *   *Discount:* Buy 2 Save $3.9 (-$7.80)
# *   **維他高鈣牛奶飲品 (Vita High Calcium Milk Drink):** Price $23.50
# *   **中國雞脊柳 (Chinese Chicken Fillet):** Price $34.90
# *   **檸黃櫻桃番茄 (Lemon Yellow Cherry Tomatoes):** Price $17.90
# *   **雀巢絲滑牛奶咖啡 3樽 (Nestle Silky Milk Coffee 3 bottles):** Price $22.00
# *   **卡士餐後 1小時雙歧桿 (Yakult Bifidus after meal 1 hour):** Price $18.90
# *   **佳之選橄欖油 (Best Choice Olive Oil):** Price $139.00
# *   **維他高鈣低脂牛奶飲品 (Vita High Calcium Low Fat Milk Drink):** Price $23.50
# *   **麵包 (Bread):** Price $16.00
# *   **全麥合桃紅莓包 (Whole Wheat Walnut Cranberry Bread):** Price $16.90
# *   **急凍三文魚扒 (兩塊裝) (Frozen Salmon Fillet (2 pieces)):** Quantity 2, Price $46.00
# *   **菜芯 (每束) (Choy Sum (per bunch)):** Price $43.80
# *   **越式香茅豬扒 (Vietnamese Lemongrass Pork Chop):** Price $32.90
# *   **丹麥皇冠丹麥無骨豬梅 (Danish Crown Boneless Pork Loin):** Price $48.00
#
# **Discounts/Promotions:**
# *   **OVER$40 ENJOY 10%:** -$6.38
# *   **5% OFF (CU):** -$28.53 (likely a Chinese University staff/student discount)
# *   **App upgrade:** -$30.00
#
# **Totals:**
# *   **小計 (Subtotal):** $514.09
# *   **ROUNDING:** -$0.09
# *   **應付金額 (Total Payable):** $514.00
#
# **Payment Information:**
# *   **Payment Method:** OCTOPUS (八達通)
# *   **扣除金額 (Amount Deducted):** $514.00
# *   **餘額 (Balance):** $48.80 (This seems to be the remaining balance on the Octopus card after the transaction, not change from the purchase itself).
# *   **上次於 2025-04-18 網上增值 (Last top-up online on 2025-04-18):** This indicates a recent top-up for the Octopus card.
#
# **Return Policy/Notes:**
# *   "如需退換或退款, 請於七天內帶同貨品及收據正本到本店。不適用於指定產品, 詳情請參閱網站。借用購物車按金除外。" (For exchange or refund, please bring the goods and the original receipt to this store within seven days. Not applicable to designated products, please refer to the website for details. Excludes shopping trolley deposit.)
# *   "Original receipt needed for refund/exchange within 7 days. Excludes selected products. Visit PNS website for details. Excludes borrow shopping trolley deposit."
# *   "百佳超級市場 (香港) 有限公司 PARKnSHOP (HK) Limited"
#
# **Barcode:**
# *   A barcode is present at the bottom: 870620413352020250419
#
# ----end----
# receipt session 5----begin----
# This picture contains a detailed receipt from a "Fusion" supermarket, which is part of PARKnSHOP (HK) Limited.
#
# Here's a breakdown of the content:
#
# **Store Information:**
# *   **Store Name:** Fusion (operated by PARKnSHOP (HK) Limited / 百佳超級市場(香港)有限公司)
# *   **Location:** Chinese University City, Basement New Staff Student Ctr Bldg., Chinese University of HK, Shatin, NT
# *   **Telephone:** 26035432
# *   **Store Number:** 00062
# *   **Cash Register Number:** 029
# *   **Cashier ID:** SC04
#
# **Transaction Details:**
# *   **Date:** 2025-04-25
# *   **Time:** 20:00:33 (8:00 PM and 33 seconds)
# *   **Receipt Number:** 0322
#
# **Purchased Items:**
# 1.  **028499 BAKERY 5:** Quantity: 2, Price: $10.00
# 2.  **089288 威蛋素肉餅 (Vegetarian Meat Patty/Cake):** Price: $36.90
# 3.  **013723 (業務用)急凍螺子肉 ((Business Use) Frozen Snail Meat):** Price: $60.80
# *   **Discount:** 5% OFF (CU-SCO) - -$5.39
#
# **Payment Summary:**
# *   **Subtotal:** $102.31
# *   **Rounding:** -$0.01
# *   **Total Amount Due:** $102.30
# *   **Payment Method:** Octopus Card
# *   **Change:** $0.00
#
# **Octopus Card Details:**
# *   **Machine Number:** 51788C
# *   **Octopus Card Number:** 172731824
# *   **Amount Deducted:** $102.30
# *   **Remaining Balance on Card:** $35.60
#
# **MoneyBack Loyalty Program Information:**
# *   **Card Number:** 9915006056*** (partially masked)
# *   **Points Earned This Time (Basic & Extra):** 495 + 20 = 515 points
# *   **Call to Action:** Download MoneyBack APP or visit www.moneyback.com.hk for more information.
# *   **Previous Activity:** Last online top-up on 2025-04-22.
#
# **Return/Exchange Policy:**
# *   Original receipt and goods required for refund/exchange within 7 days.
# *   Not applicable to designated products (refer to website for details).
# *   Excludes shopping trolley deposit.
#
# **Background Information (partially visible):**
# *   Some Chinese characters and English text are visible behind the receipt, appearing to be from a poster or sign, including phrases like "ch plastic," "while the h," "ff not who," and "ge takea."
#
# ----end----
# receipt session 6----begin----
# This picture is a retail receipt, likely from a supermarket or grocery store, detailing a purchase and payment information.
#
# Here's a breakdown of the content:
#
# **Header Information:**
# *   **Card no:** 9915006056***
# *   **MoneyBack Point Balance:** 263
# *   **Points Earned in this purchase:** 37 (basic & extra pts included)
# *   **Website for MoneyBack App:** www.moneyback.com.hk
#
# **Itemized List & Discounts:**
# *   **PLASTIC BAG CHARGIN:** $1.00
# *   **COUPON:** $0.00
# *   **AMATAKE SEPARATABLES:**
#     *   SP: $20.00 QTY: 2 = $40.00
#     *   Buy 2 Save $5: -$5.00
# *   **FOOD NATION NATURAL:**
#     *   SP: $27.00 QTY: 2 = $54.00
#     *   Buy 2 Save $4: -$4.00
# *   **BROCCOLI (CHINA):**
#     *   SP: $3.90 QTY: 2 = $7.80
#     *   Buy 2 Save $0.8: -$0.80
# *   **HIGH BRIX ORANGE FA:** $32.00
# *   **FARMFRESH BONELESS C:** $34.90
# *   **SUPREME BALANCE FZ N:** $42.00
# *   **POMELO (TAIWAN):** $9.50
# *   **MB $200 get 5% off:** -$10.52
# *   **5% OFF (CU-SCO):** -$9.99
#
# **Summary of Charges:**
# *   **SUBTOTAL:** $190.89
# *   **ROUNDING:** -$0.09
# *   **VISA (Total Paid):** $190.80
# *   **CHANGE:** $0.00
#
# **Payment Details:**
# *   **Payment Method:** GP.VISA
# *   **APP Label:** VISA CREDIT
# *   **Ref No:** 251005029018264
# *   **PAN (Card Number):** 400612******4269
# *   **MID:** 088028095111004
# *   **Trace#:** 018264
# *   **RRN:** 527812571139
# *   **TID:** 51960776
# *   **APPR#:** 268592
# *   **Exp. Date:** **/**
#
# The receipt shows a purchase totaling $190.80 paid via VISA, with several items, quantity discounts, and percentage-based discounts applied.
# ----end----
# receipt session 7----begin----
# Here is an analysis of the receipt content:
#
# **Header Information:**
# *   Card no: 9915006056***
# *   MoneyBack Point Balance: 655
# *   Points Earned in this purchase: 62
# *   (basic &amp; extra pts. included)
# *   Find out more! Download MoneyBack App or visit our website www.moneyback.com.hk
#
# **Purchased Items and Prices:**
# *   **309455 PLASTIC BAG CHARGIN:** $1.00
# *   **073806 GOLDEN PINEAPPLE (P):** $22.00
#     *   Discount: -$11.00
# *   **包裝變形 (097)** (Packaging deformation/damaged packaging - likely a discount reason or specific item code)
# *   **146479 SHINY MEADOW 4.0 PRO**
#     *   SP: $43.00 QTY: 2
#     *   Total: $86.00
#     *   Buy 2 Save: -$36.00
# *   **317590 YUMMY HOUSE SLICED M**
#     *   SP: $16.60 QTY: 2
#     *   Total: $33.20
#     *   Buy 2 Save: -$3.20
# *   **075504 LEMON (SOUTH AFRICA)**
#     *   SP: $5.90 QTY: 3
#     *   Total: $17.70
#     *   Buy 3 Save: -$2.80
# *   **495326 SELECT 4PLY BATHROOM**
#     *   SP: $32.90 QTY: 2
#     *   Total: $65.80
#     *   MB PRICE $55/2S (MoneyBack Price for 2 items)
#     *   Discount: -$10.80
# *   **089259 FARMFRESH AU LEAN BE:** $39.90
# *   **048729 SPICES(SHALLOT/GING)**
#     *   SP: $10.90 QTY: 2
#     *   Total: $21.80
# *   **055421 MR VEGETABLE PREPACK:** $10.90
# *   **049718 GARLIC 3PCS (CHINA):** $3.90
# *   **084640 FARMFRESH CARA CARA:** $26.00
# *   **190742 YAKULT PROBIOTICS DR:** $13.90
# *   **046530 BESTWAY FROZEN A**
#     *   SP: $16.00 QTY: 2
#     *   Total: $32.00
# *   **473400 SUNTORY WHITE ALCOHO:** $11.90
# *   **378846 MUSO SICHUAN SPIC S:** $10.00
# *   **5% OFF (CU):** -$16.56
#
# **Summary:**
# *   **SUBTOTAL:** $315.64
# *   **ROUNDING:** -$0.04
# *   **VISA (Total Paid):** $315.60
# *   **CHANGE:** $0.00
#
# **Payment Details:**
# *   **GP. VISA**
# *   **APP Label:** VISA CREDIT
# *   **參考編號 Ref No:** 250828003014376
# *   **卡號 PAN:** 400612******4269
# *   **MID:** 088028095111001
# *   **Trace#:** 014376
# *   **RRN:** 524012586710
# *   **AID:** A0000000031010
# *   **TC:** 27EA16E01BCC448C
# *   **TVR:** 0000000000
# *   **exp.:** **/**
# *   **TID:** 51960773
# *   **授權碼 APPR#:** 167723
# *   **批次號 Batch#:** 000521
# *   **TSI:** 0000
# *   **ATC:** 0025
#
# The receipt details a grocery purchase with various food items, a plastic bag charge, and some household goods. Several items were purchased with special offers or discounts. The total amount paid was $315.60 via VISA.
# ----end----

# %% [markdown]
# ## 3. Evaluation Code
#
# * Make sure your LLM return a single float as the answer, stored in `query1_answer` and `query2_answer`
# * Run the following code blocks: (1) If the blocks does not return any error, then your chain design is correct. Otherwise, please check your chain design.
#
# * Do not modify `query_1_costs` and `query_2_costs`

# %%
def test_query(answer, ground_truth_costs):
    # Convert string to float if necessary
    if isinstance(answer, str):
        answer = float(answer)

    # Calculate the ground truth sum once for clarity
    expected_total = sum(ground_truth_costs)

    # Check if the answer is within +/- $2 of the expected total
    assert abs(answer - expected_total) <= 2

# %%
prompt3 = ChatPromptTemplate.from_messages([
    ("system", "You are a result interpretation assistant. You recognize the receipt information from each receipt and sum it up, return with a simple string sum value"),
    ("human", [
        {"type": "text", "text": "Here are the receipts' payment without content for each receipt: {payment_without_discount}"},
        {"type": "text", "text": "return only the sumed string value without the $ notation,"}

    ]),
])
result_trans = prompt3|llm

# %% [markdown]
# Run the following code block to evaluate query 1:
# > How much money did I spend in total for these bills?

# %%
query_1_costs = [394.7, 316.1, 140.8, 514.0, 102.3, 190.8, 315.6] # do not modify this

# Redefine prompt1 to correctly use 'text' type for receipt content
prompt1 = ChatPromptTemplate.from_messages([
    ("system", "You are a cost saving assistant. You analyze receipt text and return the total amount spent as a float. Make sure the output is a single float number."),
    ("human", [
        {"type": "text", "text": "Here are the receipts' content extracted from the images: {receipt_text_input}"},
         {"type": "text", "text": "I separate the session through ----begin---- and ----end---- which denote the beginning and end of a receipt session respectively"},
         {"type": "text", "text": "Try to recognize and use the key feature with total payment amount or total paid for submission，notice that each session will have 1 total amount spended"},
        {"type": "text", "text": "sum the total amount spent from each extracted receipts session. Return the string summed value which could be converted into float through float function, only remain the total sum value without the calculation process."}

    ]),
])



full_query1_pipeline = prompt1 | llm
query1_answer_raw_message = full_query1_pipeline.invoke({"receipt_text_input":receipt_content})
result_transformed=result_trans.invoke({"payment_without_discount":query1_answer_raw_message})
query1_answer=float(result_transformed.content)
print(query1_answer)
# Out:
# 1974.3

# %%
test_query(query1_answer, query_1_costs)

# %%
sum(query_1_costs)
# Out:
# 1974.3

# %% [markdown]
# Run the following code block to evaluate query 2:
# > How much would I have had to pay without the discount?

# %%
query_2_costs = [480.20, 392.20, 160.10, 590.80, 107.70, 221.20, 396.00] # do not modify this

# %%
prompt2 = ChatPromptTemplate.from_messages([
    ("system", "You are a discount helpful assistant. You prudent review every item in each receipt session and calculate the amount to pay without the discount"),
    ("human", [
        {"type": "text", "text": "Here are the receipts' discount related content extracted from the images: {receipt_text_input}"},
        {"type": "text", "text": "I separate the session through ----begin---- and ----end---- which denote the beginning and end of a receipt session respectively"},
        {"type": "text", "text": "You check both the detail of item listed and the discount part if have. Then you compare whether there are one discount being added twice "},
        {"type": "text", "text": "Don not recognize as discount if the sign start with -, checking with the item include the keyword like discount,%off and other similar meaning expression."},
        {"type": "text", "text": "add up and check the amount to pay without the discount for each receipt session. Don't add back one discount twice"}
    ]),
])

full_query2_pipeline = prompt2 | llm
discount_info=llm.invoke(f"Please acrroding to the {receipt_content}, keep the item and part related to discount, and the total payment for each session. This response will be used for payment without discount calculation, so please be careful and utilize the keyward for recognition and extraction. The session are separated in a --begin-- --end-- pattern, please follow this pattern to generate response")
query2_answer_raw_message = full_query2_pipeline.invoke({"receipt_text_input":discount_info.content})
query2_answer_raw_message.content
# Out:
# 'Here is the amount to pay without the discount for each receipt session:\n\n**Receipt Session 1:**\n*   Total Payment: $394.70\n*   Discounts: $12.40 + $12.40 + $12.40 + $12.80 + $10.80 + $3.90 + $20.78 = $85.48\n*   Amount to pay without discount: $394.70 + $85.48 = **$480.18**\n\n**Receipt Session 2:**\n*   Total Payment: $316.10\n*   Discounts: $9.80 + $6.00 + $5.90 + $5.80 + $2.00 + $10.00 + $20.00 + $16.59 = $76.09\n*   Amount to pay without discount: $316.10 + $76.09 = **$392.19**\n\n**Receipt Session 3:**\n*   Total Payment: $140.80\n*   Discounts: $4.00 + $7.80 + $7.42 = $19.22\n*   Amount to pay without discount: $140.80 + $19.22 = **$160.02**\n\n**Receipt Session 4:**\n*   Total Payment: $514.00\n*   Discounts: $4.00 + $7.80 + $6.38 + $28.53 + $30.00 = $76.71\n*   Amount to pay without discount: $514.00 + $76.71 = **$590.71**\n\n**Receipt Session 5:**\n*   Total Payment: $102.30\n*   Discounts: $5.39\n*   Amount to pay without discount: $102.30 + $5.39 = **$107.69**\n\n**Receipt Session 6:**\n*   Total Payment: $190.80\n*   Discounts: $5.00 + $4.00 + $0.80 + $10.52 + $9.99 = $30.31\n*   Amount to pay without discount: $190.80 + $30.31 = **$221.11**\n\n**Receipt Session 7:**\n*   Total Payment: $315.60\n*   Discounts: $11.00 + $36.00 + $3.20 + $2.80 + $10.80 + $16.56 = $80.36\n*      Amount to pay without discount: $315.60 + $80.36 = **$395.96**'

# %%
prompt4 = ChatPromptTemplate.from_messages([
    ("system", "You are a result interpretation assistant. You recognize the receipt information from each receipt and sum it up, return with a simple string sum value"),
    ("human", [
        {"type": "text", "text": "Here are the receipts' payment without content for each receipt: {payment_without_discount}"},
        {"type": "text", "text": "return only the sumed string value without the $ notation,"}

    ]),
])
result_trans2 = prompt4|llm
result_transformed = result_trans2.invoke({"payment_without_discount":query2_answer_raw_message})
query2_answer=float(result_transformed.content)

# %%
test_query(query2_answer, query_2_costs)

# %%
query2_answer
# Out:
# 2347.86
